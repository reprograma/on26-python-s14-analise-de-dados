# %% [markdown]
# ## DESAFIO SEMANA 14 - REPROGRAMA
#
# Criar um notebook de análise exploratória com todas as etapas de coleta, limpeza, análise e visualização com base de dados da Olist.
#
# Requisitos:
# - Formular o mínimo de 4 perguntas para responder com suas análises;
# - Utilizar pelo menos 3 bases de dados da Olist;
# - Criar pelo menos 3 gráficos.
# - Exporte sua base final.
#
#
# Submeta uma pasta que contenha:
# - o arquivo .ipynb com sua análise exploratória;
# - a base final criada por você no formato .csv;
# - as bases da olist em .csv que você utilizou na criação da sua analise exploratória.

# %%
import pandas as pd

# %% [markdown]
# ## Coleta das três bases de dados escolhidas:

# %%
df_payments = pd.read_csv('datasets_olist/olist_order_payments_dataset.csv')
df_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_sellers = pd.read_csv('datasets_olist/olist_sellers_dataset.csv')
df_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_products = pd.read_csv('datasets_olist/product_category_name_translation.csv')
df_products
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# ## Limpeza

# %%
df_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Insights
#
# A base 'olist_order_payments_dataset.csv' possui um grande conjunto de dados com 103.886 entradas, o que indica que há uma quantidade significativa de informações disponíveis para análise.
# Não há valores ausentes em nenhuma das colunas, o que facilita a análise, pois não é necessário lidar com dados faltantes.

# %%
df_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# ## Insights
#
# O base de dados 'olist_sellers_dataset.csv' possui informações sobre 3.095 vendedores, o que pode ser útil para análises relacionadas à distribuição geográfica dos vendedores ou à avaliação do desempenho de cada vendedor.
#
# Novamente, não há valores ausentes nas colunas, o que simplifica nossa análise.
#
# As colunas 'seller_city' e 'seller_state' fornecem informações sobre a localização geográfica dos vendedores, o que pode ser útil para análises geoespaciais.
#
# A coluna 'seller_zip_code_prefix' contém informações sobre os códigos postais dos vendedores e pode ser útil para análises de localização.

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Insights
#
# O conjunto de dados de categorias de produtos contém 71 categorias diferentes. Essas categorias podem ser usadas para agrupar produtos e realizar análises relacionadas à distribuição de produtos nas categorias.
#
# A existência de uma coluna com nomes de categorias em inglês sugere que os dados podem ser multilíngues, o que pode ser relevante para análises de mercado global ou para determinar a popularidade de categorias em diferentes regiões do mundo.
#
# Não há valores ausentes nas colunas, o que torna a análise mais fácil.

# %%
# Vamos descobrir qual  é a distribuição de tipos de pagamento nos pedidos
payment_type_counts = df_payments['payment_type'].value_counts()
payment_type_counts
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
# E agora, visualizar em um gráfico
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.barplot(x=payment_type_counts.index, y=payment_type_counts.values, hue=payment_type_counts.index, legend=False)
plt.title('Distribuição de Tipos de Pagamento nos Pedidos')
plt.xlabel('Tipo de Pagamento')
plt.ylabel('Contagem')
plt.xticks(rotation=45)

plt.show()

# %%
# Para saber qual o valor médio dos pagamentos

valor_medio_pagamento = df['payment_value'].mean()
df_valor_medio_pagamento = pd.DataFrame({'Valor Médio de Pagamento': [valor_medio_pagamento]})
df_valor_medio_pagamento
# Out:
#    Valor Médio de Pagamento
# 0                     129.0

# %%
# Vamos calcular a quantidade de vendedores por estado plotar num gráfico o resultado

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.countplot(data=df_sellers, x='seller_state', hue='seller_state', palette='Set2', legend=False)
plt.title('Distribuição de Vendedores por Estado')
plt.xlabel('Estado')
plt.ylabel('Contagem de Vendedores')

plt.xticks(rotation=45)

plt.show()

# %%
# Por fim, um gráfico com as 5 categorias mais vendidas

categoria_counts = df_products['product_category_name'].value_counts().head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x=categoria_counts.index, y=categoria_counts.values, hue=categoria_counts.index, dodge=False)
plt.title('As 5 Categorias de Produtos Mais Vendidas')
plt.xlabel('Categoria de Produto')
plt.ylabel('Número de Produtos Vendidos')
plt.xticks(rotation=45)
plt.show()

# %%
# voltar aqui para finalizar: gerar dataframe com as colunas das bases de dados usadas
