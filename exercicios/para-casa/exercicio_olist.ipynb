# %% [markdown]
# #  Ánalise de dados da Basde de dados Olist
#
# Base de dados disponibilizada pela Olist, uma empresa de e-commerce. Essa base de dados
# é composta por 9 tabelas, porém para esse exercicio iremos utilizar apenas 5, que são:
#
# - itens dos pedidos (olist_order_items_dataset)
# - detalhes de pagamento dos pedidos (olist_order_payments_dataset)
# - detalhes do consumidor que fez os pedidos (olist_customers_dataset)
# - detalhes de geolocalização do consumidor (olist_geolocation_dataset)
# - detalhes dos produtos (olist_products_dataset)
# - detalhes dos vendedores (olist_sellers_dataset)
#
# [_Fonte_](https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce)

# %%
#importar
import pandas as pd

# %%
df_pedidos = pd.read_csv('datasets_olist/olist_order_items_dataset.csv')
df_pedidos
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_pag_pedidos = pd.read_csv('datasets_olist/olist_order_payments_dataset.csv')
df_pag_pedidos
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# Nomes das colunas df_pag_pedidos:
#
# * 'order_id' - ID do pedido
# * 'payment_sequential' - Sequencial de pagamento
# * 'payment_type' - Tipo de pagamento
# * 'payment_installments' - Parcelas de pagamento
# * 'payment_value' - Valor do pagamento

# %%
df_cons_pedidos = pd.read_csv('datasets_olist/olist_customers_dataset.csv')
df_cons_pedidos
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# Nomes das colunas df_cons_pedidos:
#
# * 'customer_id' - ID do cliente
# * 'customer_unique_id' - ID único do cliente
# * 'customer_zip_code_prefix' - Prefixo do CEP do cliente
# * 'customer_city' - Cidade do cliente
# * 'customer_state' - Estado do cliente

# %%
df_geoloc_consumidor = pd.read_csv('datasets_olist/olist_geolocation_dataset.csv')
df_geoloc_consumidor
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# Nomes das colunas geoloc_consumidor:
#
# * 'geolocation_zip_code_prefix' - Prefixo do CEP da geolocalização
# * 'geolocation_lat' - Latitude da geolocalização
# * 'geolocation_lng' - Longitude da geolocalização
# * 'geolocation_city' - Cidade da geolocalização
# * 'geolocation_state' - Estado da geolocalização

# %%
df_produtos = pd.read_csv('datasets_olist/olist_products_dataset.csv')
df_produtos
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# Nomes das colunas df_produtos:
#
# * 'product_id' - ID do produto
# * 'product_category_name' - Nome da categoria do produto
# * 'product_name_lenght' - Comprimento do nome do produto
# * 'product_description_lenght' - Comprimento da descrição do produto
# * 'product_photos_qty' - Quantidade de fotos do produto
# * 'product_weight_g' - Peso do produto em gramas
# * 'product_length_cm' - Comprimento do produto em centímetros
# * 'product_height_cm' - Altura do produto em centímetros
# * 'product_width_cm' - Largura do produto em centímetros

# %%
df_vendedores = pd.read_csv('datasets_olist/olist_sellers_dataset.csv')
df_vendedores
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# Nomes das colunas df_vendedores:
#
# * 'seller_id' - ID do vendedor
# * 'seller_zip_code_prefix' - Prefixo do CEP do vendedor
# * 'seller_city' - Cidade do vendedor
# * 'seller_state' - Estado do vendedor

# %% [markdown]
# ## Limpando os dados

# %%
# Vamos entender um pouquinho melhor dos nossos dados
df_pag_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_pag_pedidos.count().isnull()
# Out:
# order_id                False
# payment_sequential      False
# payment_type            False
# payment_installments    False
# payment_value           False
# dtype: bool

# %%
df_vendedores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df_vendedores.count().isnull()
# Out:
# seller_id                 False
# seller_zip_code_prefix    False
# seller_city               False
# seller_state              False
# dtype: bool

# %%
df_produtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_produtos.count().isnull()
# Out:
# product_id                    False
# product_category_name         False
# product_name_lenght           False
# product_description_lenght    False
# product_photos_qty            False
# product_weight_g              False
# product_length_cm             False
# product_height_cm             False
# product_width_cm              False
# dtype: bool

# %%
df_geoloc_consumidor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_geoloc_consumidor.count().isnull()
# Out:
# geolocation_zip_code_prefix    False
# geolocation_lat                False
# geolocation_lng                False
# geolocation_city               False
# geolocation_state              False
# dtype: bool

# %%
# Vamos começar nossa limpeza filtrando somente as colunas que desejamos utilizar
columns_drop = ['geolocation_lat', 'geolocation_lng']
df_geoloc_consumidor = df_geoloc_consumidor.drop(columns_drop, axis=1)
df_geoloc_consumidor
# Out:
#          geolocation_zip_code_prefix geolocation_city geolocation_state
# 0                               1037        sao paulo                SP
# 1                               1046        sao paulo                SP
# 2                               1046        sao paulo                SP
# 3                               1041        sao paulo                SP
# 4                               1035        sao paulo                SP
# ...                              ...              ...               ...
# 1000158                        99950         tapejara                RS
# 1000159                        99900   getulio vargas                RS
# 1000160                        99950         tapejara                RS
# 1000161                        99980  david canabarro                RS
# 1000162                        99950         tapejara                RS
#
# [1000163 rows x 3 columns]

# %%
df_cons_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Juntando as tabelas

# %%
# Por padrão é realizado o merge dos dados com o inner join
# Jutando os df pedidos e itens de pedidos
df_olist_v0 = pd.merge(df_cons_pedidos, df_geoloc_consumidor, left_on='customer_zip_code_prefix', right_on='geolocation_zip_code_prefix', how='inner')
df_olist_v0
# Out:
#                                customer_id                customer_unique_id  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# ...                                    ...                               ...
# 15083450  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083451  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083452  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083453  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
# 15083454  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
#
# ...

# %%
df_olist_v0.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#    geolocation_zip_code_prefix geolocation_city geolocation_state
# 0                        14409           franca                SP
# 1                        14409           franca                SP
# ...

# %%
columns_drop = ['customer_zip_code_prefix']
df_olist_v0 = df_olist_v0.drop(columns_drop, axis=1)
df_olist_v0
# Out:
#                                customer_id                customer_unique_id  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# ...                                    ...                               ...
# 15083450  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083451  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083452  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083453  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
# 15083454  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
#
# ...

# %%
columns_drop = ['customer_unique_id','customer_city', 'customer_state']
df_olist_v0 = df_olist_v0.drop(columns_drop, axis=1)
df_olist_v0
# Out:
#                                customer_id  geolocation_zip_code_prefix  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7                        14409
# 1         06b8999e2fba1a1fbc88172c00ba8bc7                        14409
# 2         06b8999e2fba1a1fbc88172c00ba8bc7                        14409
# 3         06b8999e2fba1a1fbc88172c00ba8bc7                        14409
# 4         06b8999e2fba1a1fbc88172c00ba8bc7                        14409
# ...                                    ...                          ...
# 15083450  d9110683c7a282144e9fc97660026a28                        74980
# 15083451  d9110683c7a282144e9fc97660026a28                        74980
# 15083452  d9110683c7a282144e9fc97660026a28                        74980
# 15083453  6fb4f2354f36e554ac80141e9128f528                        99043
# 15083454  6fb4f2354f36e554ac80141e9128f528                        99043
#
#               geolocation_city geolocation_state
# 0                       franca                SP
# ...

# %%
df_olist_v0 = pd.merge(df_olist_v0, df_vendedores, left_on='geolocation_zip_code_prefix', right_on='seller_zip_code_prefix', how='inner')
df_olist_v0
# Out:
#                                customer_id  geolocation_zip_code_prefix  \
# 0         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 1         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 2         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 3         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 4         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# ...                                    ...                          ...
# 11492510  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492511  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492512  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492513  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492514  7fb62e47282b83f023cf1fef8d8309c9                         4319
#
#          geolocation_city geolocation_state                         seller_id  \
# ...

# %%
columns_drop = ['seller_zip_code_prefix','seller_city', 'seller_state']
df_olist_v0 = df_olist_v0.drop(columns_drop, axis=1)
df_olist_v0
# Out:
#                                customer_id  geolocation_zip_code_prefix  \
# 0         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 1         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 2         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 3         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 4         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# ...                                    ...                          ...
# 11492510  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492511  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492512  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492513  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492514  7fb62e47282b83f023cf1fef8d8309c9                         4319
#
#          geolocation_city geolocation_state                         seller_id
# ...

# %%
df_olist_v = pd.merge(df_pag_pedidos, df_pedidos, on='order_id', how='inner')
df_olist_v
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 117596  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 117597  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 117598  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 117599  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 117600  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value  order_item_id  \
# ...

# %%
df_olist_v = pd.merge(df_olist_v, df_olist_v, on='product_id', how='inner')
df_olist_v
# Out:
#                                order_id_x  payment_sequential_x  \
# 0        b81ef226f3fe1789b1e8b2acac839d17                     1
# 1        b81ef226f3fe1789b1e8b2acac839d17                     1
# 2        d86305c284cecff56c7ee9d3fbd4f8d6                     1
# 3        d86305c284cecff56c7ee9d3fbd4f8d6                     1
# 4        a9810da82917af2d9aefd1278f1dcfa0                     1
# ...                                   ...                   ...
# 4412176  6a87a0371f263aa8c1779c2c115c1427                     1
# 4412177  e0657085c2b6297a32f39efa200cdf72                     1
# 4412178  9ac048d7ffebba67d54456aa9ec07d7e                     1
# 4412179  c45067032fd84f4cf408730ff5205568                     1
# 4412180  32609bbb3dd69b3c066a6860554a77bf                     1
#
#         payment_type_x  payment_installments_x  payment_value_x  \
# 0          credit_card                       8            99.33
# 1          credit_card                       8            99.33
# ...

# %%
columns_drop = ['order_id_x','payment_sequential_x','payment_type_x','payment_installments_x','payment_value_x']
df_olist_v = df_olist_v.drop(columns_drop, axis=1)
df_olist_v
# Out:
#          order_item_id_x                        product_id  \
# 0                      1  af74cc53dcffc8384b29e7abfa41902b
# 1                      1  af74cc53dcffc8384b29e7abfa41902b
# 2                      1  af74cc53dcffc8384b29e7abfa41902b
# 3                      1  af74cc53dcffc8384b29e7abfa41902b
# 4                      1  a630cc320a8c872f9de830cf121661a3
# ...                  ...                               ...
# 4412176                1  1f58e3c365e615b33b2b30b068d7578a
# 4412177                1  e2336d327209ca849dca5afda036f842
# 4412178                1  0dcb1adbafdcc389972874b01fa249b8
# 4412179                1  fea2f92877b647dc07ea8e3f4aa2cf3f
# 4412180                1  848ef0a103ee21407d1fbd0f7e7ae179
#
#                               seller_id_x shipping_limit_date_x  price_x  \
# 0        213b25e6f54661939f11710a6fddb871   2018-05-02 22:15:09    79.80
# 1        213b25e6f54661939f11710a6fddb871   2018-05-02 22:15:09    79.80
# ...

# %%
columns_drop = ['order_item_id_x', 'payment_sequential_y','order_item_id_y', 'price_x', 'price_y','freight_value_y', 'seller_id_y', 'shipping_limit_date_y']
df_olist_v = df_olist_v.drop(columns_drop, axis=1)
df_olist_v
# Out:
#                                product_id                       seller_id_x  \
# 0        af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 1        af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 2        af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 3        af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 4        a630cc320a8c872f9de830cf121661a3  eaf6d55068dea77334e8477d3878d89e
# ...                                   ...                               ...
# 4412176  1f58e3c365e615b33b2b30b068d7578a  2a5b78b41cd05baeac8df54c6606b92c
# 4412177  e2336d327209ca849dca5afda036f842  a8739afb32aaa45e01815ca76f76f54b
# 4412178  0dcb1adbafdcc389972874b01fa249b8  2f74af7a0ee5636f12c2336f9fffed47
# 4412179  fea2f92877b647dc07ea8e3f4aa2cf3f  406822777a0b9eb5c50e442dd4cd3ec5
# 4412180  848ef0a103ee21407d1fbd0f7e7ae179  3d621842b2ed28e2b474132480edac3c
#
#         shipping_limit_date_x  freight_value_x  \
# ...

# %%
#Suponha que você deseja tirar uma amostra de cada DataFrame
sample_fraction = 0.01

# Tire uma amostra do primeiro DataFrame (df_olist_v0)
df_olist_v0_amostra = df_olist_v0.sample(frac=sample_fraction, random_state=1)

# Tire uma amostra do segundo DataFrame (df_olist_v)
df_olist_v_amostra = df_olist_v.sample(frac=sample_fraction, random_state=1)

# %%
df_olist_v0_amostra.head()
df_olist_v0_amostra.shape
# Out:
# (114925, 5)

# %%
df_olist_v_amostra.head()
df_olist_v_amostra.shape
# Out:
# (44122, 8)

# %%
# Realize a junção dos DataFrames de amostra
df_olist_amostra = pd.merge(df_olist_v0_amostra, df_olist_v_amostra, left_on='seller_id', right_on='seller_id_x', how='inner')
df_olist_amostra.head()
# Out:
#                         customer_id  geolocation_zip_code_prefix  \
# 0  85edc80a16b4badbc1e58061b6ba26e3                        22240
# 1  85edc80a16b4badbc1e58061b6ba26e3                        22240
# 2  85edc80a16b4badbc1e58061b6ba26e3                        22240
# 3  85edc80a16b4badbc1e58061b6ba26e3                        22240
# 4  85edc80a16b4badbc1e58061b6ba26e3                        22240
#
#   geolocation_city geolocation_state                         seller_id  \
# 0   rio de janeiro                RJ  46dc3b2cc0980fb8ec44634e21d2718e
# 1   rio de janeiro                RJ  46dc3b2cc0980fb8ec44634e21d2718e
# 2   rio de janeiro                RJ  46dc3b2cc0980fb8ec44634e21d2718e
# 3   rio de janeiro                RJ  46dc3b2cc0980fb8ec44634e21d2718e
# 4   rio de janeiro                RJ  46dc3b2cc0980fb8ec44634e21d2718e
#
#                          product_id                       seller_id_x  \
# 0  bea978771d1c453faf756fa71f3bdd70  46dc3b2cc0980fb8ec44634e21d2718e
# ...

# %% [markdown]
# # Ánalises

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ánalise
df_olist_v0
# Out:
#                                customer_id  geolocation_zip_code_prefix  \
# 0         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 1         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 2         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 3         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# 4         4f2d8ab171c80ec8364f7c12e35b23ad                        13056
# ...                                    ...                          ...
# 11492510  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492511  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492512  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492513  7fb62e47282b83f023cf1fef8d8309c9                         4319
# 11492514  7fb62e47282b83f023cf1fef8d8309c9                         4319
#
#          geolocation_city geolocation_state                         seller_id
# ...

# %% [markdown]
# #### Quais são os 10 Estados com mais clientes?

# %%
# Define o estilo de fundo
plt.style.use('dark_background')

# Cria uma figura
plt.figure(figsize=(10, 6))

# Ordena os estados geográficos com base na contagem de clientes e pega os 10 maiores
top_10_states = df_olist_v0['geolocation_state'].value_counts().head(10).index

# Gere um gráfico de contagem de clientes por estado geográfico
sns.countplot(data=df_olist_v0, x='geolocation_state', order=top_10_states)

# Adiciona os valores nas barras do gráfico
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='white', xytext=(0, 5), textcoords='offset points')

# Define o título e rótulos dos eixos
plt.title('Top 10 Estados com Mais Clientes')
plt.xlabel('Estado Geográfico')
plt.ylabel('Contagem de Clientes')

# Rotaciona os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45)

# Exibe o gráfico
plt.show()

# %% [markdown]
# ##### Qual é Valor dos pagamentos por estado geográfico?

# %%
# Agrupe os dados por estado geográfico e calcule a soma dos valores de pagamento
group_dados = df_olist_amostra.groupby('geolocation_state')['payment_value_y'].sum().reset_index()

# Crie o gráfico de barras empilhadas
plt.figure(figsize=(10, 6))
sns.barplot(data=group_dados, x='geolocation_state', y='payment_value_y', palette='viridis')
plt.title('Valor Total de Pagamento por Estado Geográfico')
plt.xlabel('Estado Geográfico')
plt.ylabel('Valor Total de Pagamento')
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp\ipykernel_380\368783477.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=group_dados, x='geolocation_state', y='payment_value_y', palette='viridis')

# %% [markdown]
# ##### Qual é a relação entre o valor do frete (freight_value_x) e o tipo de pagamento (payment_type_y)?

# %%
# Média do valor do frete por tipo de pagamento
avg_freight_by_payment = df_olist_amostra.groupby('payment_type_y')['freight_value_x'].mean()
print(avg_freight_by_payment)

# Gráfico de barras da média do valor do frete por tipo de pagamento
avg_freight_by_payment.plot(kind='bar', figsize=(10, 6))
plt.title('Média do Valor do Frete por Tipo de Pagamento')
plt.xlabel('Tipo de Pagamento')
plt.ylabel('Média do Valor do Frete')
plt.show()
# Out:
# payment_type_y
# boleto         17.530080
# credit_card    17.363810
# debit_card     16.275750
# voucher        17.034593
# Name: freight_value_x, dtype: float64

# %% [markdown]
# ##### Existe alguma sazonalidade nas datas de envio (shipping_limit_date_x) em relação ao valor do pagamento (payment_value_y)?

# %%
# Converter as datas de envio para o formato de data
df_olist_amostra['shipping_limit_date_x'] = pd.to_datetime(df_olist_amostra['shipping_limit_date_x'])

# Gráfico de dispersão das datas de envio em relação ao valor do pagamento
plt.figure(figsize=(10, 6))
plt.scatter(df_olist_amostra['shipping_limit_date_x'], df_olist_amostra['payment_value_y'], alpha=0.5)
plt.title('Relação entre Data de Envio e Valor do Pagamento')
plt.xlabel('Data de Envio')
plt.ylabel('Valor do Pagamento')
plt.show()

# %% [markdown]
# ## Salvar em CSV

# %%
nome_do_arquivo = 'amostra_df.csv'

# Exporte o DataFrame para um arquivo CSV
df_olist_amostra.to_csv(nome_do_arquivo, index=False)

print(f'O DataFrame foi exportado para {nome_do_arquivo}')
# Out:
# O DataFrame foi exportado para amostra_df.csv
